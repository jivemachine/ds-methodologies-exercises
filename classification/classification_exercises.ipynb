# %%
import pandas as pd
import numpy as np


import acquire
import pydataset

# %% [markdown]
# ### 1.) Use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
df_iris = pydataset.data("iris")

# %% [markdown]
# - print the first 3 rows

# %%
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# - print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %% [markdown]
# - print the column names

# %%
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# - print the data type of each column

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
# Sepal.Length    150 non-null float64
# Sepal.Width     150 non-null float64
# Petal.Length    150 non-null float64
# Petal.Width     150 non-null float64
# Species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# - print the summary statistics for each of the numeric variables. Would you recommend rescaling the data based on these statistics?

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# #### I don't see a reason to scale them unless these measurements were done with different units. (i.e. cm and inches)

# %% [markdown]
# ### 2.) Read Table1_CustDetails the excel module dataset, Excel_Exercises.xlsx, into a dataframe, df_excel

# %%
df_excel = pd.read_excel('Spreadsheets_Exercises_Solutions.xlsx', sheet_name='Table1_CustDetails')

# %%
df_excel.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
# 3  0011-IGKFF    Male                  1     Yes         No              1
# 4  0013-EXCHZ  Female                  1     Yes         No              1
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0                 1              1      Mailed check             65.6
# 1                 1              0      Mailed check             59.9
# 2                 2              0  Electronic check             73.9
# 3                 2              0  Electronic check             98.0
# 4                 2              0      Mailed check             83.9
#
#    total_charges churn
# 0         593.30    No
# 1         542.40    No
# ...

# %% [markdown]
# - assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df_excel.head(100)

# %% [markdown]
# - print the number of rows of your original dataframe

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 12 columns):
# customer_id          7049 non-null object
# gender               7049 non-null object
# is_senior_citizen    7049 non-null int64
# partner              7049 non-null object
# dependents           7049 non-null object
# phone_service        7049 non-null int64
# internet_service     7049 non-null int64
# contract_type        7049 non-null int64
# payment_type         7049 non-null object
# monthly_charges      7049 non-null float64
# total_charges        7038 non-null float64
# churn                7049 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 661.0+ KB

# %% [markdown]
# - print the first 5 column names

# %%
df_excel.columns[:5]
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %% [markdown]
# - print the column names that have a data type of object

# %%
filtered_excel_dtypes = df_excel.dtypes[df_excel.dtypes == np.object]

filtered_excel_dtypes
# Out:
# customer_id     object
# gender          object
# partner         object
# dependents      object
# payment_type    object
# churn           object
# dtype: object

# %% [markdown]
# - compute the range for each of the numeric variables.

# %%
df_excel.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7049.000000    7049.000000       7049.000000    7049.000000
# mean            0.162009       1.324585          1.222585       0.690878
# std             0.368485       0.642709          0.779068       0.833757
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_charges  total_charges
# count      7049.000000    7038.000000
# mean         64.747014    2283.043883
# std          30.099460    2266.521984
# min          18.250000      18.800000
# 25%          35.450000     401.587500
# 50%          70.350000    1397.100000
# 75%          89.850000    3793.775000
# ...

# %%
range_is_senior_citizen = range(0,1)
range_phone_service = range(0,2)
range_internet_service = range(0, 2)
range_contract_type = range(0,2)
range_monthly_charges = range(18, 118)
ranged_total_charges = range(18,8_684)

# %% [markdown]
# ### 3.) Read the data from this google sheet into a dataframe, df_google

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_googlesheet = pd.read_csv(csv_export_url)

# %% [markdown]
# - print the first 3 rows

# %%
df_googlesheet.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# - print the number of rows and columns

# %%
df_googlesheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - print the column names

# %%
df_googlesheet.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - print the data type of each column

# %%
df_googlesheet.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# - print the summary statistics for each of the numeric variables

# %%
df_googlesheet.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - print the unique values for each of your categorical variables

# %%
df_googlesheet.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # In a new python module, acquire.py:

# %% [markdown]
# ### 1.) get_titanic_data: returns the titanic data from the codeup data science database as a pandas data frame.

# %%
df = acquire.get_titanic_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37197c01fb44> in <module>
# ----> 1 df = acquire.get_titanic_data()
#
# NameError: name 'acquire' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 2.) get_iris_data: returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids.

# %%
df = acquire.get_iris_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-14d14507a64c> in <module>
# ----> 1 df = acquire.get_iris_data()
#
# NameError: name 'acquire' is not defined

# %%
df.head()
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
# 3           1               4           4.6          3.1           1.5
# 4           1               5           5.0          3.6           1.4
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa
# 3          0.2       setosa
# 4          0.2       setosa

# %% [markdown]
# ***********************************************************

# %% [markdown]
# # Exploratory Analysis Exercises
#
# Continue in your classification_exercises.ipynb notebook. Use the iris dataset.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

import acquire
import prepare

# %% [markdown]
# ### 1.) Split data into train (70%) & test (30%) samples.

# %%
df = acquire.get_iris_data()

# %%
df.head()
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
# 3           1               4           4.6          3.1           1.5
# 4           1               5           5.0          3.6           1.4
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa
# 3          0.2       setosa
# 4          0.2       setosa

# %%
train, test = train_test_split(df, 
                random_state=830, train_size=.70, test_size=.30 )

# %%
train.shape, test.shape
# Out:
# ((105, 7), (45, 7))

# %% [markdown]
# ### 2.) Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis is the variable name, the y-axis is the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %%
df_melt = pd.melt(train[['sepal_length', 
        'sepal_width', 'petal_length',
        'petal_width', 'species_name']],
        'species_name', var_name='measurement')

plt.figure(figsize=(8,6))

p = sns.swarmplot(x='measurement', y='value', hue='species_name',
     data=df_melt)

plt.show()

# %% [markdown]
# ### 3.) Create 4 subplots (2 rows x 2 columns) of scatterplots

# %% [markdown]
# - sepal_length x sepal_width
# - petal_length x petal_width
# - sepal_area x petal_area
# - sepal_length x petal_length

# %%
df.head()
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
# 3           1               4           4.6          3.1           1.5
# 4           1               5           5.0          3.6           1.4
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa
# 3          0.2       setosa
# 4          0.2       setosa

# %%
train['sepal_area'] = train.sepal_length * train.sepal_width
train['petal_area'] = train.petal_length * train.petal_width

# %%
plt.rc('figure',figsize=(14, 8))
plt.rc('font', size=14)
plt.suptitle("analysing petal / sepal measurements")

plt.subplot(221)
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species_name', data=train, legend=False)

plt.subplot(222)
sns.scatterplot(x='petal_length', y='petal_width', hue='species_name', data=train)

plt.subplot(223)
sns.scatterplot(x='sepal_area', y='petal_area', hue='species_name', data=train, legend=False)

plt.subplot(224)
sns.scatterplot(x="sepal_length", y='petal_length', hue='species_name', data=train, legend=False)

plt.show()

# %% [markdown]
# - Make your figure size 14 x 8. What are your takeaways?

# %% [markdown]
# These flowers need to be grouped differently, otherwise there isin't much correlation between sepal size and petal size. unless we're analysing petal_width against petal length.

# %% [markdown]
# ### 4.) Create a heatmap of each variable layering correlation coefficient on top.

# %%
df.head(3)
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa

# %% [markdown]
# - we use heatmap with lineasr correlartion to find features that correlate well with the target variable
# - w/ classification, our tagret is discrete b/c it's a class/category
# - our heatmap here is helping identify which input feature correlates with each other
# - why is that important: some/many classification algorithims mathmetically assume independance of features.

# %%
plt.title("Heatmap of feature correlations")
heatmap_df = train.drop(columns=['species_name', 'species_id', 'measurement_id'])
sns.heatmap(heatmap_df.corr() , annot=True, cmap='winter', fmt='.1%')
plt.show()

# %% [markdown]
# ### 5.) Create a scatter matrix visualizing the interaction of each variable

# %%
g = sns.PairGrid(train.drop(columns=['species_id']), hue='species_name')
g = g.map(plt.scatter)

# %% [markdown]
# ### 6.) Is the sepal length significantly different in virginica compared to versicolor? Run an experiment to test this.

# %% [markdown]
# - must include null hypothesis, alternative hypothesis, t-test, results, summary

# %% [markdown]
# - $H_0$: the difference in sepal length between virginica and versicolor is insignificant.
# - $H_a$: the difference in sepal length between virginica and versicolor is substantial.

# %% [markdown]
# - We will test if the sepal length of virginica is significantly different than that of the versicolor.

# %%
train.groupby('species_name').sepal_length.mean()
# Out:
# species_name
# setosa        5.011765
# versicolor    5.930556
# virginica     6.508571
# Name: sepal_length, dtype: float64

# %%
train.groupby('species_name').sepal_length.median()
# Out:
# species_name
# setosa        5.0
# versicolor    5.8
# virginica     6.5
# Name: sepal_length, dtype: float64

# %%
train.groupby('species_name').sepal_length.mean().plot.bar(ec='black', fc='blue')

# %%
train.groupby('species_name').sepal_length.median().plot.bar(ec='black', fc='blue')

# %% [markdown]
# - If there is difference, then variable sepal_length is a good choice to keep as a feature.
# - We can use a t-test here, as sepal_length is somewhat normally distributed.

# %%
from scipy import stats
df2 = train[train.species_name == 'virginica']
df3 = train[train.species_name == 'versicolor']

alpha = .01
t, p = stats.ttest_ind(df2.sepal_length, df3.sepal_length)

if p < alpha:
    print('we reject the null hypothesis')
else:
    print("we fail to reject the null hypothesis")
# Out:
# we reject the null hypothesis
